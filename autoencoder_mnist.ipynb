# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import numpy as np

# Define the dimensions
input_dim = 784  # Example for flattened 28x28 images
encoding_dim = 64  # Size of the latent space

# Define the encoder
input_data = Input(shape=(input_dim,))
encoded = Dense(256, activation='relu')(input_data)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Define the decoder
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(256, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

# Combine encoder and decoder into an autoencoder model
autoencoder = Model(input_data, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Prepare the data (example with MNIST dataset)
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Train the autoencoder
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 8s 25ms/step - loss: 0.0557 - val_loss: 0.0295
# Epoch 2/50
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0239 - val_loss: 0.0189
# Epoch 3/50
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0171 - val_loss: 0.0148
# Epoch 4/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0140 - val_loss: 0.0127
# Epoch 5/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0124 - val_loss: 0.0115
# Epoch 6/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0113 - val_loss: 0.0104
# Epoch 7/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0104 - val_loss: 0.0097
# Epoch 8/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 9/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0093 - val_loss: 0.0089
# Epoch 10/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0089 - val_loss: 0.0084
# Epoch 11/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 12/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 13/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 14/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 15/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 16/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 17/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 18/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 19/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 20/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 21/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 22/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 23/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 24/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 25/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 26/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 27/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 28/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 29/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 30/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 31/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 32/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 33/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 34/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 35/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 36/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 37/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 38/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 39/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 40/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 41/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 42/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 43/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 44/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 45/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 46/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 47/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 48/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 49/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 50/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0045 - val_loss: 0.0045
